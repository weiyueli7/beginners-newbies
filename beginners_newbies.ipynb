# %%
import pandas as pd
import numpy as np
import os

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from beginners_newbies import *

# %%
path = os.path.join('data', 'beginner.csv')
df = pd.read_csv(path)
df
# Out:
#        YEAR  SERIAL  MONTH    HWTFINL           CPSID  ASECFLAG  HFLAG  \
# 0      2015   16566      3        NaN               0       1.0    NaN
# 1      2020   49554      6  1930.4505  20200504991400       NaN    NaN
# 2      2019   94327      3        NaN               0       1.0    NaN
# 3      2011   14553      3        NaN  20091201475800       1.0    NaN
# 4      2018   31356      3        NaN  20170102597500       1.0    NaN
# ...     ...     ...    ...        ...             ...       ...    ...
# 54732  2020   41349     10   766.1293  20191004211300       NaN    NaN
# 54733  2011   76658      3        NaN  20100300901100       1.0    NaN
# 54734  2021   65040     11   873.0294  20201006551800       NaN    NaN
# 54735  2020   57273     12  4327.6454  20201005723900       NaN    NaN
# 54736  2017   94654      3        NaN               0       1.0    NaN
#
#        ASECWTH  REGION  STATEFIP  ...    BPL  EMPSTAT   OCC  UHRSWORKT  \
# ...

# %%
# Out:
# 1
